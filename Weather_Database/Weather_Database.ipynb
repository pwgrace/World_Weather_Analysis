# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 732

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description=city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | mataura
# Processing Record 3 of Set 1 | borba
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | mahebourg
# Processing Record 6 of Set 1 | inhambane
# Processing Record 7 of Set 1 | bac lieu
# Processing Record 8 of Set 1 | georgetown
# Processing Record 9 of Set 1 | vaini
# Processing Record 10 of Set 1 | sinegorye
# Processing Record 11 of Set 1 | new norfolk
# Processing Record 12 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | hermanus
# Processing Record 15 of Set 1 | nouadhibou
# Processing Record 16 of Set 1 | jalu
# Processing Record 17 of Set 1 | hithadhoo
# Processing Record 18 of Set 1 | atuona
# Processing Record 19 of Set 1 | hobart
# Processing Record 20 of Set 1 | avarua
# Processing Record 21 of Set 1 | ponta do sol
# Processing Record 22 of Set 1 | provideniya
# Processing Record 23 of Set 1 | qaqortoq
# Processing Record 24 of Set 1 | noormarkku
# Processing Record 25 of Set 1 | rikitea
# Processing Record 26 of Set 1 | pimentel
# Processing Record 27 of Set 1 | sao joao da barra
# Processing Record 28 of Set 1 | walvis bay
# Processing Record 29 of Set 1 | manokwari
# Processing Record 30 of Set 1 | chuy
# Processing Record 31 of Set 1 | butaritari
# Processing Record 32 of Set 1 | lompoc
# Processing Record 33 of Set 1 | nikolskoye
# Processing Record 34 of Set 1 | piacabucu
# Processing Record 35 of Set 1 | geraldton
# Processing Record 36 of Set 1 | palora
# Processing Record 37 of Set 1 | puerto ayora
# Processing Record 38 of Set 1 | san jose
# Processing Record 39 of Set 1 | turan
# Processing Record 40 of Set 1 | busselton
# Processing Record 41 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 1 | zhireken
# Processing Record 43 of Set 1 | port alfred
# Processing Record 44 of Set 1 | ancud
# Processing Record 45 of Set 1 | riyadh
# Processing Record 46 of Set 1 | harlingen
# Processing Record 47 of Set 1 | narsaq
# Processing Record 48 of Set 1 | chokurdakh
# Processing Record 49 of Set 1 | vardo
# Processing Record 50 of Set 1 | bima
# Processing Record 1 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 2 | osoyoos
# Processing Record 3 of Set 2 | lasa
# Processing Record 4 of Set 2 | alofi
# Processing Record 5 of Set 2 | palembang
# Processing Record 6 of Set 2 | nuuk
# Processing Record 7 of Set 2 | orzhytsya
# Processing Record 8 of Set 2 | vila
# Processing Record 9 of Set 2 | fortuna
# Processing Record 10 of Set 2 | castro
# Processing Record 11 of Set 2 | byron bay
# Processing Record 12 of Set 2 | norman wells
# Processing Record 13 of Set 2 | east london
# Processing Record 14 of Set 2 | lorengau
# Processing Record 15 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 2 | port elizabeth
# Processing Record 17 of Set 2 | sistranda
# Processing Record 18 of Set 2 | mehamn
# Processing Record 19 of Set 2 | cape town
# Processing Record 20 of Set 2 | arawa
# Processing Record 21 of Set 2 | dudinka
# Processing Record 22 of Set 2 | iskateley
# Processing Record 23 of Set 2 | salalah
# Processing Record 24 of Set 2 | pacific grove
# Processing Record 25 of Set 2 | codrington
# Processing Record 26 of Set 2 | quelimane
# Processing Record 27 of Set 2 | pisco
# Processing Record 28 of Set 2 | ushtobe
# Processing Record 29 of Set 2 | barrow
# Processing Record 30 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 31 of Set 2 | khani
# Processing Record 32 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 2 | mayya
# Processing Record 34 of Set 2 | vagur
# Processing Record 35 of Set 2 | meulaboh
# Processing Record 36 of Set 2 | saint-philippe
# Processing Record 37 of Set 2 | san patricio
# Processing Record 38 of Set 2 | miranorte
# City not found. Skipping...
# Processing Record 39 of Set 2 | luderitz
# Processing Record 40 of Set 2 | maarianhamina
# Processing Record 41 of Set 2 | goderich
# Processing Record 42 of Set 2 | yellowknife
# Processing Record 43 of Set 2 | poddorye
# Processing Record 44 of Set 2 | grindavik
# Processing Record 45 of Set 2 | kruisfontein
# Processing Record 46 of Set 2 | rawannawi
# City not found. Skipping...
# Processing Record 47 of Set 2 | aflu
# City not found. Skipping...
# Processing Record 48 of Set 2 | korla
# Processing Record 49 of Set 2 | marystown
# Processing Record 50 of Set 2 | bethel
# Processing Record 1 of Set 3 | hilo
# Processing Record 2 of Set 3 | stromness
# Processing Record 3 of Set 3 | general roca
# Processing Record 4 of Set 3 | berdigestyakh
# Processing Record 5 of Set 3 | torbay
# Processing Record 6 of Set 3 | homer
# Processing Record 7 of Set 3 | sola
# Processing Record 8 of Set 3 | port keats
# Processing Record 9 of Set 3 | pangnirtung
# Processing Record 10 of Set 3 | ramnagar
# Processing Record 11 of Set 3 | barela
# Processing Record 12 of Set 3 | laguna
# Processing Record 13 of Set 3 | rjukan
# Processing Record 14 of Set 3 | upernavik
# Processing Record 15 of Set 3 | jingdezhen
# Processing Record 16 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 17 of Set 3 | banda aceh
# Processing Record 18 of Set 3 | ribeira grande
# Processing Record 19 of Set 3 | kahului
# Processing Record 20 of Set 3 | coihaique
# Processing Record 21 of Set 3 | cabo san lucas
# Processing Record 22 of Set 3 | sitarganj
# Processing Record 23 of Set 3 | alibag
# Processing Record 24 of Set 3 | bredasdorp
# Processing Record 25 of Set 3 | banjar
# Processing Record 26 of Set 3 | twin falls
# Processing Record 27 of Set 3 | khuzhir
# Processing Record 28 of Set 3 | constitucion
# Processing Record 29 of Set 3 | moche
# Processing Record 30 of Set 3 | toktogul
# Processing Record 31 of Set 3 | mahina
# Processing Record 32 of Set 3 | quatre cocos
# Processing Record 33 of Set 3 | jiayuguan
# Processing Record 34 of Set 3 | satka
# Processing Record 35 of Set 3 | ahipara
# Processing Record 36 of Set 3 | linden
# Processing Record 37 of Set 3 | souillac
# Processing Record 38 of Set 3 | bosaso
# Processing Record 39 of Set 3 | agadez
# Processing Record 40 of Set 3 | sao filipe
# Processing Record 41 of Set 3 | katsuura
# Processing Record 42 of Set 3 | esperance
# Processing Record 43 of Set 3 | tubinskiy
# Processing Record 44 of Set 3 | atlantis
# Processing Record 45 of Set 3 | kapaa
# Processing Record 46 of Set 3 | takestan
# Processing Record 47 of Set 3 | mount gambier
# Processing Record 48 of Set 3 | carnarvon
# Processing Record 49 of Set 3 | namatanai
# Processing Record 50 of Set 3 | westport
# Processing Record 1 of Set 4 | leua
# Processing Record 2 of Set 4 | valdivia
# Processing Record 3 of Set 4 | tasiilaq
# Processing Record 4 of Set 4 | roma
# Processing Record 5 of Set 4 | pevek
# Processing Record 6 of Set 4 | kaitangata
# Processing Record 7 of Set 4 | khatanga
# Processing Record 8 of Set 4 | hasaki
# Processing Record 9 of Set 4 | bathsheba
# Processing Record 10 of Set 4 | prachuap khiri khan
# Processing Record 11 of Set 4 | khaga
# Processing Record 12 of Set 4 | santiago del estero
# Processing Record 13 of Set 4 | atar
# Processing Record 14 of Set 4 | chapais
# Processing Record 15 of Set 4 | ocos
# Processing Record 16 of Set 4 | makakilo city
# Processing Record 17 of Set 4 | krasnaya gora
# Processing Record 18 of Set 4 | plettenberg bay
# Processing Record 19 of Set 4 | haines junction
# Processing Record 20 of Set 4 | along
# Processing Record 21 of Set 4 | yulara
# Processing Record 22 of Set 4 | biak
# Processing Record 23 of Set 4 | lebu
# Processing Record 24 of Set 4 | mar del plata
# Processing Record 25 of Set 4 | thompson
# Processing Record 26 of Set 4 | uddevalla
# Processing Record 27 of Set 4 | brownwood
# Processing Record 28 of Set 4 | victoria
# Processing Record 29 of Set 4 | sompeta
# Processing Record 30 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 31 of Set 4 | phun phin
# City not found. Skipping...
# Processing Record 32 of Set 4 | airai
# Processing Record 33 of Set 4 | roald
# Processing Record 34 of Set 4 | tuktoyaktuk
# Processing Record 35 of Set 4 | severo-kurilsk
# Processing Record 36 of Set 4 | pochutla
# Processing Record 37 of Set 4 | utiroa
# City not found. Skipping...
# Processing Record 38 of Set 4 | guerrero negro
# Processing Record 39 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 40 of Set 4 | jamestown
# Processing Record 41 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 4 | port macquarie
# Processing Record 43 of Set 4 | balkanabat
# Processing Record 44 of Set 4 | nanchang
# Processing Record 45 of Set 4 | morehead
# Processing Record 46 of Set 4 | george town
# Processing Record 47 of Set 4 | wairoa
# Processing Record 48 of Set 4 | klaksvik
# Processing Record 49 of Set 4 | nanortalik
# Processing Record 50 of Set 4 | mayo
# Processing Record 1 of Set 5 | dikson
# Processing Record 2 of Set 5 | lucapa
# Processing Record 3 of Set 5 | dandong
# Processing Record 4 of Set 5 | magdalena
# Processing Record 5 of Set 5 | kalmunai
# Processing Record 6 of Set 5 | nsanje
# Processing Record 7 of Set 5 | taksimo
# Processing Record 8 of Set 5 | pitimbu
# Processing Record 9 of Set 5 | isangel
# Processing Record 10 of Set 5 | san vicente
# Processing Record 11 of Set 5 | batagay-alyta
# Processing Record 12 of Set 5 | maldonado
# Processing Record 13 of Set 5 | kokkola
# Processing Record 14 of Set 5 | cartagena del chaira
# Processing Record 15 of Set 5 | boende
# Processing Record 16 of Set 5 | arraial do cabo
# Processing Record 17 of Set 5 | kailua
# Processing Record 18 of Set 5 | djibo
# Processing Record 19 of Set 5 | tiarei
# Processing Record 20 of Set 5 | nabire
# Processing Record 21 of Set 5 | batticaloa
# Processing Record 22 of Set 5 | port-gentil
# Processing Record 23 of Set 5 | bratsk
# Processing Record 24 of Set 5 | arumbavur
# Processing Record 25 of Set 5 | revda
# Processing Record 26 of Set 5 | aksarka
# Processing Record 27 of Set 5 | pangkalanbuun
# Processing Record 28 of Set 5 | sitka
# Processing Record 29 of Set 5 | qaanaaq
# Processing Record 30 of Set 5 | vila franca do campo
# Processing Record 31 of Set 5 | kodiak
# Processing Record 32 of Set 5 | praia
# Processing Record 33 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 5 | buala
# Processing Record 35 of Set 5 | galway
# Processing Record 36 of Set 5 | marawi
# Processing Record 37 of Set 5 | amapa
# Processing Record 38 of Set 5 | tazmalt
# Processing Record 39 of Set 5 | hay river
# Processing Record 40 of Set 5 | saint george
# Processing Record 41 of Set 5 | aykhal
# Processing Record 42 of Set 5 | lerwick
# Processing Record 43 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 44 of Set 5 | miri
# Processing Record 45 of Set 5 | faya
# Processing Record 46 of Set 5 | cidreira
# Processing Record 47 of Set 5 | kirakira
# Processing Record 48 of Set 5 | cayenne
# Processing Record 49 of Set 5 | sant
# Processing Record 50 of Set 5 | port lincoln
# Processing Record 1 of Set 6 | gazojak
# Processing Record 2 of Set 6 | kodar
# Processing Record 3 of Set 6 | evensk
# Processing Record 4 of Set 6 | azimur
# City not found. Skipping...
# Processing Record 5 of Set 6 | bambous virieux
# Processing Record 6 of Set 6 | grand gaube
# Processing Record 7 of Set 6 | iranshahr
# Processing Record 8 of Set 6 | furukawa
# Processing Record 9 of Set 6 | abnub
# Processing Record 10 of Set 6 | inta
# Processing Record 11 of Set 6 | vrangel
# Processing Record 12 of Set 6 | tiksi
# Processing Record 13 of Set 6 | iqaluit
# Processing Record 14 of Set 6 | palmerston north
# Processing Record 15 of Set 6 | la ronge
# Processing Record 16 of Set 6 | bluff
# Processing Record 17 of Set 6 | brae
# Processing Record 18 of Set 6 | poum
# Processing Record 19 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 20 of Set 6 | dongsheng
# Processing Record 21 of Set 6 | candiis
# Processing Record 22 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 6 | kibuye
# Processing Record 24 of Set 6 | dalby
# Processing Record 25 of Set 6 | juba
# Processing Record 26 of Set 6 | nizwa
# Processing Record 27 of Set 6 | chirongui
# Processing Record 28 of Set 6 | keningau
# Processing Record 29 of Set 6 | lavrentiya
# Processing Record 30 of Set 6 | mangan
# Processing Record 31 of Set 6 | dutse
# Processing Record 32 of Set 6 | atasu
# Processing Record 33 of Set 6 | tual
# Processing Record 34 of Set 6 | beira
# Processing Record 35 of Set 6 | ambilobe
# Processing Record 36 of Set 6 | kavieng
# Processing Record 37 of Set 6 | kollam
# Processing Record 38 of Set 6 | saskylakh
# Processing Record 39 of Set 6 | marsabit
# Processing Record 40 of Set 6 | bengkulu
# Processing Record 41 of Set 6 | melfi
# Processing Record 42 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 6 | havre-saint-pierre
# Processing Record 44 of Set 6 | salta
# Processing Record 45 of Set 6 | altay
# Processing Record 46 of Set 6 | guiratinga
# Processing Record 47 of Set 6 | nome
# Processing Record 48 of Set 6 | flinders
# Processing Record 49 of Set 6 | progreso
# Processing Record 50 of Set 6 | barcelos
# Processing Record 1 of Set 7 | lazaro cardenas
# Processing Record 2 of Set 7 | adrar
# Processing Record 3 of Set 7 | worland
# Processing Record 4 of Set 7 | mocambique
# City not found. Skipping...
# Processing Record 5 of Set 7 | cabedelo
# Processing Record 6 of Set 7 | narasannapeta
# Processing Record 7 of Set 7 | sobolevo
# Processing Record 8 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 7 | the valley
# Processing Record 10 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 7 | lulea
# Processing Record 12 of Set 7 | mezen
# Processing Record 13 of Set 7 | longyearbyen
# Processing Record 14 of Set 7 | vlakhopoulon
# Processing Record 15 of Set 7 | roebourne
# Processing Record 16 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 17 of Set 7 | shingu
# Processing Record 18 of Set 7 | meridian
# Processing Record 19 of Set 7 | krasnoselkup
# Processing Record 20 of Set 7 | mareeba
# Processing Record 21 of Set 7 | dinajpur
# Processing Record 22 of Set 7 | kyzyl-suu
# Processing Record 23 of Set 7 | asau
# Processing Record 24 of Set 7 | joensuu
# Processing Record 25 of Set 7 | linqu
# Processing Record 26 of Set 7 | maneadero
# Processing Record 27 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 28 of Set 7 | hervey bay
# Processing Record 29 of Set 7 | san juan
# Processing Record 30 of Set 7 | awjilah
# Processing Record 31 of Set 7 | shiringushi
# Processing Record 32 of Set 7 | kijang
# Processing Record 33 of Set 7 | ewa beach
# Processing Record 34 of Set 7 | markala
# Processing Record 35 of Set 7 | vostok
# Processing Record 36 of Set 7 | tromso
# Processing Record 37 of Set 7 | helena
# Processing Record 38 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 39 of Set 7 | port augusta
# Processing Record 40 of Set 7 | camopi
# Processing Record 41 of Set 7 | obama
# Processing Record 42 of Set 7 | deming
# Processing Record 43 of Set 7 | susanville
# Processing Record 44 of Set 7 | tuatapere
# Processing Record 45 of Set 7 | warrnambool
# Processing Record 46 of Set 7 | chicama
# Processing Record 47 of Set 7 | ishigaki
# Processing Record 48 of Set 7 | lodja
# Processing Record 49 of Set 7 | nong phai
# Processing Record 50 of Set 7 | araouane
# Processing Record 1 of Set 8 | qasigiannguit
# Processing Record 2 of Set 8 | aklavik
# Processing Record 3 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 4 of Set 8 | manadhoo
# Processing Record 5 of Set 8 | baykit
# Processing Record 6 of Set 8 | cukai
# Processing Record 7 of Set 8 | te anau
# Processing Record 8 of Set 8 | san rafael
# Processing Record 9 of Set 8 | erzin
# Processing Record 10 of Set 8 | rauma
# Processing Record 11 of Set 8 | acapulco
# Processing Record 12 of Set 8 | adre
# Processing Record 13 of Set 8 | luwuk
# Processing Record 14 of Set 8 | cherskiy
# Processing Record 15 of Set 8 | marquette
# Processing Record 16 of Set 8 | staryy nadym
# Processing Record 17 of Set 8 | knysna
# Processing Record 18 of Set 8 | orichi
# Processing Record 19 of Set 8 | ambo
# Processing Record 20 of Set 8 | sur
# Processing Record 21 of Set 8 | matara
# Processing Record 22 of Set 8 | faanui
# Processing Record 23 of Set 8 | wawa
# Processing Record 24 of Set 8 | namibe
# Processing Record 25 of Set 8 | kurumkan
# Processing Record 26 of Set 8 | half moon bay
# Processing Record 27 of Set 8 | skagastrond
# City not found. Skipping...
# Processing Record 28 of Set 8 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 30 of Set 8 | kavaratti
# Processing Record 31 of Set 8 | san luis
# Processing Record 32 of Set 8 | saryshagan
# City not found. Skipping...
# Processing Record 33 of Set 8 | sakakah
# Processing Record 34 of Set 8 | uruacu
# Processing Record 35 of Set 8 | sawtell
# Processing Record 36 of Set 8 | bull savanna
# Processing Record 37 of Set 8 | tezu
# Processing Record 38 of Set 8 | coulihaut
# City not found. Skipping...
# Processing Record 39 of Set 8 | alice springs
# Processing Record 40 of Set 8 | loanda
# Processing Record 41 of Set 8 | sao jose da coroa grande
# Processing Record 42 of Set 8 | dingle
# Processing Record 43 of Set 8 | lubao
# Processing Record 44 of Set 8 | barhi
# Processing Record 45 of Set 8 | ippy
# Processing Record 46 of Set 8 | urman
# Processing Record 47 of Set 8 | vila velha
# Processing Record 48 of Set 8 | sinkat
# City not found. Skipping...
# Processing Record 49 of Set 8 | anadyr
# Processing Record 50 of Set 8 | oum hadjer
# Processing Record 1 of Set 9 | bowen
# Processing Record 2 of Set 9 | pemagatsel
# Processing Record 3 of Set 9 | derzhavinsk
# Processing Record 4 of Set 9 | sorland
# Processing Record 5 of Set 9 | rio gallegos
# Processing Record 6 of Set 9 | hamilton
# Processing Record 7 of Set 9 | komsomolskiy
# Processing Record 8 of Set 9 | lipin bor
# Processing Record 9 of Set 9 | ipameri
# Processing Record 10 of Set 9 | romny
# Processing Record 11 of Set 9 | tauranga
# Processing Record 12 of Set 9 | college place
# Processing Record 13 of Set 9 | luang prabang
# Processing Record 14 of Set 9 | deputatskiy
# Processing Record 15 of Set 9 | ixtapa
# Processing Record 16 of Set 9 | antofagasta
# Processing Record 17 of Set 9 | hohhot
# Processing Record 18 of Set 9 | van buren
# Processing Record 19 of Set 9 | ofunato
# Processing Record 20 of Set 9 | izumo
# Processing Record 21 of Set 9 | porbandar
# Processing Record 22 of Set 9 | miracatu
# Processing Record 23 of Set 9 | portland
# Processing Record 24 of Set 9 | turukhansk
# Processing Record 25 of Set 9 | sahuaripa
# Processing Record 26 of Set 9 | mugur-aksy
# Processing Record 27 of Set 9 | pitea
# Processing Record 28 of Set 9 | bereda
# Processing Record 29 of Set 9 | sain alto
# Processing Record 30 of Set 9 | zapolyarnyy
# Processing Record 31 of Set 9 | marienburg
# Processing Record 32 of Set 9 | dunedin
# Processing Record 33 of Set 9 | marsh harbour
# Processing Record 34 of Set 9 | obluche
# City not found. Skipping...
# Processing Record 35 of Set 9 | vao
# Processing Record 36 of Set 9 | hellin
# Processing Record 37 of Set 9 | carutapera
# Processing Record 38 of Set 9 | christchurch
# Processing Record 39 of Set 9 | krasnoarmeysk
# Processing Record 40 of Set 9 | okhotsk
# Processing Record 41 of Set 9 | sindor
# Processing Record 42 of Set 9 | noumea
# Processing Record 43 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 44 of Set 9 | novodugino
# Processing Record 45 of Set 9 | coahuayana
# Processing Record 46 of Set 9 | hofn
# Processing Record 47 of Set 9 | belyy yar
# Processing Record 48 of Set 9 | launceston
# Processing Record 49 of Set 9 | redlands
# Processing Record 50 of Set 9 | manzhouli
# Processing Record 1 of Set 10 | grand-santi
# Processing Record 2 of Set 10 | solnechnyy
# Processing Record 3 of Set 10 | tautira
# Processing Record 4 of Set 10 | nhulunbuy
# Processing Record 5 of Set 10 | majene
# Processing Record 6 of Set 10 | sabang
# Processing Record 7 of Set 10 | mana
# Processing Record 8 of Set 10 | trairi
# Processing Record 9 of Set 10 | mookane
# Processing Record 10 of Set 10 | belmonte
# Processing Record 11 of Set 10 | lock haven
# Processing Record 12 of Set 10 | caborca
# Processing Record 13 of Set 10 | wanaka
# Processing Record 14 of Set 10 | zhangzhou
# Processing Record 15 of Set 10 | pauini
# Processing Record 16 of Set 10 | morgan city
# Processing Record 17 of Set 10 | moses lake
# Processing Record 18 of Set 10 | ayan
# Processing Record 19 of Set 10 | mantua
# Processing Record 20 of Set 10 | quang ngai
# Processing Record 21 of Set 10 | cedar city
# Processing Record 22 of Set 10 | mamit
# Processing Record 23 of Set 10 | northam
# Processing Record 24 of Set 10 | zhigansk
# Processing Record 25 of Set 10 | sapao
# City not found. Skipping...
# Processing Record 26 of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing Record 27 of Set 10 | ocampo
# Processing Record 28 of Set 10 | san quintin
# Processing Record 29 of Set 10 | muborak
# Processing Record 30 of Set 10 | balakhta
# Processing Record 31 of Set 10 | saldanha
# Processing Record 32 of Set 10 | north platte
# Processing Record 33 of Set 10 | freeport
# Processing Record 34 of Set 10 | tekirdag
# Processing Record 35 of Set 10 | porto novo
# Processing Record 36 of Set 10 | mahanje
# Processing Record 37 of Set 10 | metu
# Processing Record 38 of Set 10 | mizur
# Processing Record 39 of Set 10 | jumla
# Processing Record 40 of Set 10 | laredo
# Processing Record 41 of Set 10 | osmena
# Processing Record 42 of Set 10 | lander
# Processing Record 43 of Set 10 | touros
# Processing Record 44 of Set 10 | gavrilovka vtoraya
# Processing Record 45 of Set 10 | muli
# Processing Record 46 of Set 10 | truro
# Processing Record 47 of Set 10 | shuyskoye
# Processing Record 48 of Set 10 | beringovskiy
# Processing Record 49 of Set 10 | bjornevatn
# Processing Record 50 of Set 10 | labuhan
# Processing Record 1 of Set 11 | kaduna
# Processing Record 2 of Set 11 | sherlovaya gora
# Processing Record 3 of Set 11 | falun
# Processing Record 4 of Set 11 | yaring
# Processing Record 5 of Set 11 | kalawit
# Processing Record 6 of Set 11 | urubicha
# Processing Record 7 of Set 11 | broken hill
# Processing Record 8 of Set 11 | savannah bight
# Processing Record 9 of Set 11 | torbat-e jam
# Processing Record 10 of Set 11 | rolim de moura
# City not found. Skipping...
# Processing Record 11 of Set 11 | belaya gora
# Processing Record 12 of Set 11 | fort nelson
# Processing Record 13 of Set 11 | saint anthony
# Processing Record 14 of Set 11 | chilac
# City not found. Skipping...
# Processing Record 15 of Set 11 | upata
# Processing Record 16 of Set 11 | nizhneudinsk
# Processing Record 17 of Set 11 | scalloway
# City not found. Skipping...
# Processing Record 18 of Set 11 | merrill
# Processing Record 19 of Set 11 | kirovskiy
# Processing Record 20 of Set 11 | gao
# Processing Record 21 of Set 11 | port-cartier
# Processing Record 22 of Set 11 | poykovskiy
# Processing Record 23 of Set 11 | hami
# Processing Record 24 of Set 11 | lagoa
# Processing Record 25 of Set 11 | kholtoson
# Processing Record 26 of Set 11 | motala
# Processing Record 27 of Set 11 | broome
# Processing Record 28 of Set 11 | bonavista
# Processing Record 29 of Set 11 | barrhead
# Processing Record 30 of Set 11 | vestmannaeyjar
# Processing Record 31 of Set 11 | xuddur
# Processing Record 32 of Set 11 | kyra
# Processing Record 33 of Set 11 | stornoway
# Processing Record 34 of Set 11 | tricase
# Processing Record 35 of Set 11 | melbu
# Processing Record 36 of Set 11 | padang
# Processing Record 37 of Set 11 | honiara
# Processing Record 38 of Set 11 | santa cruz
# Processing Record 39 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 40 of Set 11 | gorontalo
# Processing Record 41 of Set 11 | luau
# Processing Record 42 of Set 11 | kendari
# Processing Record 43 of Set 11 | santa maria
# Processing Record 44 of Set 11 | omboue
# Processing Record 45 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 46 of Set 11 | krompachy
# Processing Record 47 of Set 11 | achisay
# City not found. Skipping...
# Processing Record 48 of Set 11 | ondjiva
# Processing Record 49 of Set 11 | mahajanga
# Processing Record 50 of Set 11 | maniitsoq
# Processing Record 1 of Set 12 | niamey
# Processing Record 2 of Set 12 | salinas
# Processing Record 3 of Set 12 | gaomi
# Processing Record 4 of Set 12 | yar-sale
# Processing Record 5 of Set 12 | samarai
# Processing Record 6 of Set 12 | palaia fokaia
# Processing Record 7 of Set 12 | norwich
# Processing Record 8 of Set 12 | itarema
# Processing Record 9 of Set 12 | raudeberg
# Processing Record 10 of Set 12 | kathu
# Processing Record 11 of Set 12 | greensburg
# Processing Record 12 of Set 12 | paamiut
# Processing Record 13 of Set 12 | kuusamo
# Processing Record 14 of Set 12 | siuna
# Processing Record 15 of Set 12 | ternate
# Processing Record 16 of Set 12 | ripon
# Processing Record 17 of Set 12 | nanlong
# Processing Record 18 of Set 12 | san ramon
# Processing Record 19 of Set 12 | kushiro
# Processing Record 20 of Set 12 | muisne
# Processing Record 21 of Set 12 | gallup
# Processing Record 22 of Set 12 | pokhara
# Processing Record 23 of Set 12 | ilulissat
# Processing Record 24 of Set 12 | necochea
# Processing Record 25 of Set 12 | talara
# Processing Record 26 of Set 12 | las vegas
# Processing Record 27 of Set 12 | husavik
# Processing Record 28 of Set 12 | lima
# Processing Record 29 of Set 12 | iisalmi
# Processing Record 30 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 31 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 32 of Set 12 | bedesa
# Processing Record 33 of Set 12 | cave spring
# Processing Record 34 of Set 12 | inirida
# Processing Record 35 of Set 12 | ormara
# Processing Record 36 of Set 12 | fukue
# Processing Record 37 of Set 12 | yantal
# Processing Record 38 of Set 12 | rocha
# Processing Record 39 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 40 of Set 12 | yelan
# Processing Record 41 of Set 12 | kaeo
# Processing Record 42 of Set 12 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 43 of Set 12 | penzance
# Processing Record 44 of Set 12 | san cristobal
# Processing Record 45 of Set 12 | key west
# Processing Record 46 of Set 12 | san lawrenz
# Processing Record 47 of Set 12 | karratha
# Processing Record 48 of Set 12 | westwood
# Processing Record 49 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 50 of Set 12 | ostrovnoy
# Processing Record 1 of Set 13 | quballat
# Processing Record 2 of Set 13 | kattivakkam
# Processing Record 3 of Set 13 | finnsnes
# Processing Record 4 of Set 13 | new haven
# Processing Record 5 of Set 13 | ageyevo
# Processing Record 6 of Set 13 | moree
# Processing Record 7 of Set 13 | mahibadhoo
# Processing Record 8 of Set 13 | konstantinovsk
# Processing Record 9 of Set 13 | shenjiamen
# Processing Record 10 of Set 13 | elko
# Processing Record 11 of Set 13 | yumen
# Processing Record 12 of Set 13 | kirensk
# Processing Record 13 of Set 13 | esso
# Processing Record 14 of Set 13 | creaca
# Processing Record 15 of Set 13 | gavle
# Processing Record 16 of Set 13 | lyaskelya
# Processing Record 17 of Set 13 | pathein
# Processing Record 18 of Set 13 | gaptsakh
# Processing Record 19 of Set 13 | hengyang
# Processing Record 20 of Set 13 | kharp
# Processing Record 21 of Set 13 | tura
# Processing Record 22 of Set 13 | przhevalskoye
# Processing Record 23 of Set 13 | ossora
# Processing Record 24 of Set 13 | lebanon
# Processing Record 25 of Set 13 | pires do rio
# Processing Record 26 of Set 13 | soe
# Processing Record 27 of Set 13 | leningradskiy
# Processing Record 28 of Set 13 | beroroha
# Processing Record 29 of Set 13 | khorixas
# Processing Record 30 of Set 13 | bar bigha
# Processing Record 31 of Set 13 | george
# Processing Record 32 of Set 13 | lahaina
# Processing Record 33 of Set 13 | coquimbo
# Processing Record 34 of Set 13 | alto araguaia
# Processing Record 35 of Set 13 | henties bay
# Processing Record 36 of Set 13 | chifeng
# Processing Record 37 of Set 13 | egvekinot
# Processing Record 38 of Set 13 | isabela
# Processing Record 39 of Set 13 | san joaquin
# Processing Record 40 of Set 13 | tucson
# Processing Record 41 of Set 13 | palmer
# Processing Record 42 of Set 13 | amberley
# Processing Record 43 of Set 13 | lichinga
# Processing Record 44 of Set 13 | weiden
# Processing Record 45 of Set 13 | cockburn harbour
# City not found. Skipping...
# Processing Record 46 of Set 13 | babanusah
# City not found. Skipping...
# Processing Record 47 of Set 13 | kodinsk
# Processing Record 48 of Set 13 | manggar
# Processing Record 49 of Set 13 | nicoya
# Processing Record 50 of Set 13 | bontang
# Processing Record 1 of Set 14 | venado tuerto
# Processing Record 2 of Set 14 | lashio
# Processing Record 3 of Set 14 | vanavara
# Processing Record 4 of Set 14 | batemans bay
# Processing Record 5 of Set 14 | laki
# Processing Record 6 of Set 14 | san alberto
# Processing Record 7 of Set 14 | chisec
# Processing Record 8 of Set 14 | san francisco
# Processing Record 9 of Set 14 | chara
# Processing Record 10 of Set 14 | alexandria
# Processing Record 11 of Set 14 | tocopilla
# Processing Record 12 of Set 14 | kangaatsiaq
# Processing Record 13 of Set 14 | nador
# Processing Record 14 of Set 14 | hobyo
# Processing Record 15 of Set 14 | mutoko
# Processing Record 16 of Set 14 | marsa matruh
# Processing Record 17 of Set 14 | muret
# Processing Record 18 of Set 14 | kihei
# Processing Record 19 of Set 14 | rafai
# Processing Record 20 of Set 14 | cap-aux-meules
# Processing Record 21 of Set 14 | arman
# Processing Record 22 of Set 14 | tomatlan
# Processing Record 23 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 24 of Set 14 | tessalit
# Processing Record 25 of Set 14 | kabompo
# Processing Record 26 of Set 14 | vangaindrano
# Processing Record 27 of Set 14 | morant bay
# Processing Record 28 of Set 14 | townsville
# Processing Record 29 of Set 14 | nazare
# Processing Record 30 of Set 14 | wecker
# Processing Record 31 of Set 14 | libertad
# Processing Record 32 of Set 14 | panukulan
# Processing Record 33 of Set 14 | olafsvik
# Processing Record 34 of Set 14 | dakar
# Processing Record 35 of Set 14 | phan rang
# City not found. Skipping...
# Processing Record 36 of Set 14 | umm kaddadah
# Processing Record 37 of Set 14 | fairbanks
# Processing Record 38 of Set 14 | mbanza-ngungu
# Processing Record 39 of Set 14 | sribne
# Processing Record 40 of Set 14 | salamiyah
# Processing Record 41 of Set 14 | kehtna
# Processing Record 42 of Set 14 | ortakoy
# Processing Record 43 of Set 14 | puerto escondido
# Processing Record 44 of Set 14 | pouebo
# Processing Record 45 of Set 14 | panama city
# Processing Record 46 of Set 14 | vavozh
# Processing Record 47 of Set 14 | gladstone
# Processing Record 48 of Set 14 | brigantine
# Processing Record 49 of Set 14 | ramos arizpe
# Processing Record 50 of Set 14 | ruteng
# Processing Record 1 of Set 15 | aripuana
# Processing Record 2 of Set 15 | dali
# Processing Record 3 of Set 15 | nishihara
# Processing Record 4 of Set 15 | tambopata
# Processing Record 5 of Set 15 | bilibino
# Processing Record 6 of Set 15 | date
# Processing Record 7 of Set 15 | monrovia
# Processing Record 8 of Set 15 | businga
# Processing Record 9 of Set 15 | kuching
# Processing Record 10 of Set 15 | antalaha
# Processing Record 11 of Set 15 | vanimo
# Processing Record 12 of Set 15 | amahai
# Processing Record 13 of Set 15 | wainwright
# Processing Record 14 of Set 15 | panaba
# Processing Record 15 of Set 15 | cururupu
# Processing Record 16 of Set 15 | puerto cabezas
# Processing Record 17 of Set 15 | asfi
# Processing Record 18 of Set 15 | lemesos
# City not found. Skipping...
# Processing Record 19 of Set 15 | najran
# Processing Record 20 of Set 15 | samos
# Processing Record 21 of Set 15 | toftir
# City not found. Skipping...
# Processing Record 22 of Set 15 | cambridge
# Processing Record 23 of Set 15 | akdepe
# Processing Record 24 of Set 15 | presidencia roque saenz pena
# Processing Record 25 of Set 15 | ndele
# Processing Record 26 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 27 of Set 15 | rio das pedras
# Processing Record 28 of Set 15 | bilma
# Processing Record 29 of Set 15 | junagarh
# Processing Record 30 of Set 15 | west odessa
# Processing Record 31 of Set 15 | kaitong
# Processing Record 32 of Set 15 | stillwater
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0      Albany      US  42.60  -73.97     70.00        73          83
# 1     Mataura      NZ -46.19  168.86     64.99        59          60
# 2       Borba      BR  -4.39  -59.59     84.83        63          67
# 3     Ushuaia      AR -54.80  -68.30     44.60        65          75
# 4   Mahebourg      MU -20.41   57.70     73.40        69          20
# 5   Inhambane      MZ -23.86   35.38     70.07        84           0
# 6    Bac Lieu      VN   9.29  105.72     77.20        86         100
# 7  Georgetown      MY   5.41  100.34     78.80        94          20
# 8       Vaini      TO -21.20 -175.20     77.00        38          40
# 9   Sinegorye      RU  62.08  150.48     30.33        92          95
#
#    Wind Speed Current Description
# 0        8.43       broken clouds
# 1       11.01       broken clouds
# 2        1.43       broken clouds
# 3        9.17       broken clouds
# 4        9.17          few clouds
# 5        5.73           clear sky
# 6        2.04     overcast clouds
# 7        3.51       moderate rain
# 8       11.41    scattered clouds
# 9        4.50     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
